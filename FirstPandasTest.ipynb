# %%
import pandas as pd

# %%
sr = pd.Series(['42','45','12'])
sr
# Out:
# 0    42
# 1    45
# 2    12
# dtype: object

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60,
    "6":80
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102,
    "6":105
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127,
    "6":140
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300,
    "6":230
  }
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300
# 6        80    105       140       230

# %%
robo = pd.read_excel(path)

# %%
robo

# %%
robo.fillna(0,inplace=True)

# %%
robo

# %%
robo.tail()
# Out:
#          Launches  Launch 1                                        Launch 2  \
# 24       Points:        0.0                                              20
# 25  Description:        0.0  If energy cell unit is not touching Water Dam.
# 26        Bonus:        0.0                                               0
# 27  Description:        0.0                                               0
# 28         Total:       0.0                                              20
#
#                                              Launch 3  \
# 24                                                 10
# 25  If Innovation Project Model is partly inside H...
# 26                                                  0
# 27                                                  0
# 28                                                 10
#
#                                              Launch 4 Launch 5 Launch 6  \
# 24                                                 15       45        0
# ...

# %%
sub = robo.loc[robo["Launches"]=="Bonus: "]

# %%
robo.iloc[26,0:5] #robo.iloc[26,:]

# %%
sub.to_excel("Robo Sub.xlsx",index=False)

# %%
sub.to_csv("Robo Sub.csv")
