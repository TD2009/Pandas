# %%
import pandas as pd

# %%
path = r"C:\Tanish\Python\Pandas\archive\uk-500.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df["salary"] = 140000

# %%
df
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web', 'salary'],
#       dtype='object')

# %%
df["first_name"].nunique()
# Out:
# 479

# %%
df["salary"].max()
# Out:
# 140000

# %%
df.isna().sum()
# Out:
# first_name      0
# last_name       0
# company_name    0
# address         0
# city            0
# county          0
# postal          0
# phone1          0
# phone2          0
# email           0
# web             0
# salary          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# first_name      0
# last_name       0
# company_name    0
# address         0
# city            0
# county          0
# postal          0
# phone1          0
# phone2          0
# email           0
# web             0
# salary          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# first_name      500
# last_name       500
# company_name    500
# address         500
# city            500
# county          500
# postal          500
# phone1          500
# phone2          500
# email           500
# web             500
# salary          500
# dtype: int64

# %%
citygroup = df.groupby("city")

# %%
for i in citygroup:
    print(i[1])
# Out:
#    first_name last_name    company_name       address             city  \
# 75      Billy     Venus  Tipton & Hurst  61 Miriam St  Abbey Road Ward
#
#             county   postal        phone1        phone2  \
# 75  Greater London  NW8 9BD  01537-356648  01703-435212
#
#                     email                           web  salary
# 75  billy.venus@yahoo.com  http://www.tiptonhurst.co.uk  140000
#   first_name  last_name        company_name      address        city  \
# 1       Evan  Zigomalas  Cap Gemini America  5 Binney St  Abbey Ward
#
#             county    postal        phone1        phone2  \
# 1  Buckinghamshire  HP11 2AX  01937-864715  01714-737668
#
#                       email                                web  salary
# 1  evan.zigomalas@gmail.com  http://www.capgeminiamerica.co.uk  140000
#     first_name last_name            company_name               address  \
# 124  Celestina     Pince  Mcallister & Murphy Pc  13 Stockdale St #779
#
# ...

# %%
citygroup = df.groupby("city").agg({"company_name":"nunique"}).reset_index()

# %%
citygroup
# Out:
#                            city  company_name
# 0               Abbey Road Ward             1
# 1                    Abbey Ward             1
# 2            Abingdon on Thames             1
# 3            Acton Central Ward             1
# 4    Acton Trussell and Bednall             1
# ..                          ...           ...
# 463                Woodham Ward             1
# 464              Woodhouse Ward             2
# 465              Woodstock Ward             1
# 466                     Yalding             1
# 467                   Yealmpton             1
#
# [468 rows x 2 columns]

# %%
citygroup[citygroup["company_name"]]
# Out:
#                                city  company_name
# 15               Astley Bridge Ward             2
# 43                            Blyth             2
# 53   Broxburn, Uphall and Winchburg             2
# 66                      Castle Ward             2
# 70              Central Buchan Ward             2
# 71                     Central Ward             3
# 76                       Chichester             2
# 85            City and Hunslet Ward             3
# 106                Darton West Ward             2
# 110                   Deepdale Ward             2
# 132                    Everton Ward             2
# 137                          Fawley             2
# 143                    Franche Ward             2
# 162                  Halliwell Ward             2
# 217  Knightsbridge and Belgravia Wa             2
# 252            Loundsley Green Ward             2
# 262                      Meads Ward             2
# 297                  Northgate Ward             2
# ...

# %%
citygroup.dtypes
# Out:
# city            object
# company_name     int64
# dtype: object

# %%
citygroup["company_name"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
citygroup.columns = ["city","company_count"]

# %%
citygroup
# Out:
#                            city  company_count
# 0               Abbey Road Ward              1
# 1                    Abbey Ward              1
# 2            Abingdon on Thames              1
# 3            Acton Central Ward              1
# 4    Acton Trussell and Bednall              1
# ..                          ...            ...
# 463                Woodham Ward              1
# 464              Woodhouse Ward              2
# 465              Woodstock Ward              1
# 466                     Yalding              1
# 467                   Yealmpton              1
#
# [468 rows x 2 columns]

# %%
citymerge = df.merge(citygroup,on="city",how="left")

# %%
citymerge
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
cityconcat = pd.concat([df,citygroup],axis=1)

# %%
cityconcat
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
pivot = pd.pivot_table(citymerge,columns="county",index="company_name",values="first_name",aggfunc="count")

# %%
pivot["Berkshire"].notnull().sum()
# Out:
# 6

# %%
pivot
# Out:
# county                          Aberdeenshire  Bath Avon  Bedfordshire  \
# company_name
# 1893 Shops                                NaN        NaN           NaN
# A 1 Plumbers Supply                       NaN        NaN           NaN
# A All In One Construction                 NaN        NaN           NaN
# A B E Doors & Windows                     NaN        NaN           NaN
# A F Supl Co Div Automtc Firing            NaN        NaN           NaN
# ...                                       ...        ...           ...
# Word & Image Workshop Inc                 NaN        NaN           NaN
# Wrangle Hill Auto Auct & Slvg             NaN        NaN           NaN
# Wstu 1450 Am Radio Station                NaN        NaN           NaN
# Wuhf Fox 31                               NaN        NaN           NaN
# Young Door Company                        NaN        NaN           NaN
#
# county                          Berkshire  Bournemouth  Brighton and Hove  \
# company_name
# ...
